# %% [markdown]
# # Key Exchange Space

# %% [markdown]
# This is a helper notebook for Week 2, where students can perform calculations "in private".  The main lecture on Friday will take place in the `Week2-Friday` notebook.

# %%
# !pip install pycryptodome
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
from Crypto.Util.number import getPrime, getRandomNBitInteger
from sympy.ntheory import n_order

# %%
# role of Alice 
a = getRandomNBitInteger(28)
a # display the integer so you don't lose access to it if the hardware resets
# Out:
# 164382127

# %%
p = 1043283653
g = 2

# %%
A = pow(2, a, p)
A
# Out:
# 285398211
