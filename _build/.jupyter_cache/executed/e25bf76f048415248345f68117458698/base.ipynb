# %%
from Crypto.Util.number import getPrime, getRandomNBitInteger
from sympy.ntheory import n_order
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from Crypto.Util.number import getPrime, getRandomNBitInteger
#       2 from sympy.ntheory import n_order
#
# ModuleNotFoundError: No module named 'Crypto'

# %%
# don't install Crypto, I think that is out of date
# !pip install pycryptodome
# Out:
# Collecting pycryptodome
#   Downloading pycryptodome-3.23.0-cp37-abi3-win_amd64.whl (1.8 MB)
# Installing collected packages: pycryptodome
# Successfully installed pycryptodome-3.23.0
# WARNING: You are using pip version 21.0.1; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.

# %%
from Crypto.Util.number import getPrime, getRandomNBitInteger
from sympy.ntheory import n_order
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from Crypto.Util.number import getPrime, getRandomNBitInteger
#       2 from sympy.ntheory import n_order
#
# ModuleNotFoundError: No module named 'Crypto'

# %%
# input is number of bits
# input is number digits when written in binary
getPrime(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # input is number of bits
#       2 # input is number digits when written in binary
# ----> 3 getPrime(5)
#
# NameError: name 'getPrime' is not defined

# %%
2**4 + 2**3 + 2**2 + 2**0
# Out:
# 29

# %%
p = getPrime(30)
p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 p = getPrime(30)
#       2 p
#
# NameError: name 'getPrime' is not defined

# %%
# Order is p-1, so 2 is a primitive root modulo 1043283653
n_order(2, p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Order is p-1, so 2 is a primitive root modulo 1043283653
# ----> 2 n_order(2, p)
#
# NameError: name 'n_order' is not defined

# %%
g = 2

# %%
getRandomNBitInteger(27)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 getRandomNBitInteger(27)
#
# NameError: name 'getRandomNBitInteger' is not defined

# %%
# public (a is displayed in the Z-KeyExchangeSpace page)
A = 285398211

# %%
# public
B = 971542416

# %%
# Computed k = pow(A, b, p)
# Keep k secret
# This is the ciphertext k*m mod p
c = 145545544
# Update: add p to m when you find m, and then search for that ISBN
