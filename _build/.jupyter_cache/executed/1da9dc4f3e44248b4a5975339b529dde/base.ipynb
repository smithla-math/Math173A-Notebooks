# %%
# !pip install pycryptodome
# Out:
# Requirement already satisfied: pycryptodome in c:\program files\python39\lib\site-packages (3.23.0)
# WARNING: You are using pip version 21.0.1; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.

# %%
from Crypto.Util.number import getPrime, getRandomNBitInteger
from sympy.ntheory import n_order, nextprime, isprime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from Crypto.Util.number import getPrime, getRandomNBitInteger
#       2 from sympy.ntheory import n_order, nextprime, isprime
#
# ModuleNotFoundError: No module named 'Crypto'

# %%
p = getPrime(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 p = getPrime(10)
#
# NameError: name 'getPrime' is not defined

# %%
p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 p
#
# NameError: name 'p' is not defined

# %%
pow(2, 10)
# Out:
# 1024

# %%
pow(2, 9)
# Out:
# 512

# %%
getPrime(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 getPrime(30)
#
# NameError: name 'getPrime' is not defined

# %%
pow(2, 29)
# Out:
# 536870912

# %%
pow(2, 30)
# Out:
# 1073741824

# %%
p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 p
#
# NameError: name 'p' is not defined

# %%
n_order(1, p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 n_order(1, p)
#
# NameError: name 'n_order' is not defined

# %%
n_order(2, p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 n_order(2, p)
#
# NameError: name 'n_order' is not defined

# %%
# Want p-1
p-1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Want p-1
# ----> 2 p-1
#
# NameError: name 'p' is not defined

# %%
n_order(0, p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 n_order(0, p)
#
# NameError: name 'n_order' is not defined

# %%
n_order(3, p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 n_order(3, p)
#
# NameError: name 'n_order' is not defined

# %%
# Check: do these orders divide the size of the group (p-1)
(p-1)/22
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Check: do these orders divide the size of the group (p-1)
# ----> 2 (p-1)/22
#
# NameError: name 'p' is not defined

# %%
(p-1)/31
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 (p-1)/31
#
# NameError: name 'p' is not defined

# %%
# Not quite what we want
22%(p-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Not quite what we want
# ----> 2 22%(p-1)
#
# NameError: name 'p' is not defined

# %%
# Fancier way to check that 22 divides p-1, using `%`
# For example, 27%11 is 5
(p-1)%22
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 # Fancier way to check that 22 divides p-1, using `%`
#       2 # For example, 27%11 is 5
# ----> 3 (p-1)%22
#
# NameError: name 'p' is not defined

# %%
gens_list = []
for g in range(1, p):
    if n_order(g, p) == p-1:
        gens_list.append(g)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 gens_list = []
# ----> 2 for g in range(1, p):
#       3     if n_order(g, p) == p-1:
#       4         gens_list.append(g)
#
# NameError: name 'p' is not defined

# %%
# Secretly this list has length phi(p-1), where phi(p-1) is the size of (Z/(p-1)Z)^x
print(gens_list)
# Out:
# []

# %%
len(gens_list)
# Out:
# 0

# %%
p-1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 p-1
#
# NameError: name 'p' is not defined

# %%
from math import gcd

# %%
# What is (Z/682Z)^x?
N = p-1
elt_list = []
for a in range(N):
    if gcd(a, N) == 1:
        elt_list.append(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # What is (Z/682Z)^x?
# ----> 2 N = p-1
#       3 elt_list = []
#       4 for a in range(N):
#
# NameError: name 'p' is not defined

# %%
len(elt_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 len(elt_list)
#
# NameError: name 'elt_list' is not defined

# %%
print(elt_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print(elt_list)
#
# NameError: name 'elt_list' is not defined

# %%
# This is still naive, still slow, but better than what I wrote in Homework 2.
def better_naive_dlog(g, h, p):
    '''This will be the first positive value x such that g^x mod p == h, if it exists'''
    y = 1 # This is g^0 mod p
    for x in range(1, p):
        # compute y = g^x mod p assuming y is currently g^(x-1) mod p
        # Could use y = pow(g, x, p), but let's take advantage of already knowing g^(x-1) mod p
        y = (y*g)%p
        if y == h:
            return x

    # If no solution exists, return None
    return None

# %%
(7**43)%101
# Out:
# 46

# %%
better_naive_dlog(7, 46, 101)
# Out:
# 43

# %%
n_order(5, 101)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 n_order(5, 101)
#
# NameError: name 'n_order' is not defined

# %%
pow(5, 87, 101)
# Out:
# 92

# %%
better_naive_dlog(5, 92, 101)
# Out:
# 12

# %%
pow(5, 12, 101)
# Out:
# 92

# %%
pow(5, 12+25, 101)
# Out:
# 92

# %%
pow(5, 62, 101)
# Out:
# 92
