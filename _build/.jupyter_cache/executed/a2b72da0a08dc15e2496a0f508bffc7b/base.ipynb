# %%
# !pip install pycryptodome
# Out:
# Requirement already satisfied: pycryptodome in c:\program files\python39\lib\site-packages (3.23.0)
# WARNING: You are using pip version 21.0.1; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.

# %%
from sympy import nextprime, isprime, factorint
from Crypto.Util.number import getPrime, getRandomNBitInteger
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from sympy import nextprime, isprime, factorint
# ----> 2 from Crypto.Util.number import getPrime, getRandomNBitInteger
#
# ModuleNotFoundError: No module named 'Crypto'

# %%
p = getPrime(100)
q = getPrime(100)
N = p*q
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 p = getPrime(100)
#       2 q = getPrime(100)
#       3 N = p*q
#
# NameError: name 'getPrime' is not defined

# %%
N
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 N
#
# NameError: name 'N' is not defined

# %%
len(str(N))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 len(str(N))
#
# NameError: name 'N' is not defined

# %%
from math import gcd

# %%
# Find e relatively prime to phi(N) = (p-1)*(q-1)
gcd(3, (p-1)*(q-1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Find e relatively prime to phi(N) = (p-1)*(q-1)
# ----> 2 gcd(3, (p-1)*(q-1))
#
# NameError: name 'p' is not defined

# %%
e = 3

# %%
d = pow(e, -1, (p-1)*(q-1))
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 d = pow(e, -1, (p-1)*(q-1))
#       2 d
#
# NameError: name 'p' is not defined

# %%
p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 p
#
# NameError: name 'p' is not defined

# %%
q
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 q
#
# NameError: name 'q' is not defined

# %%
# Choose a base x relatively prime to N (very weak restriction)
x = getRandomNBitInteger(80)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Choose a base x relatively prime to N (very weak restriction)
# ----> 2 x = getRandomNBitInteger(80)
#
# NameError: name 'getRandomNBitInteger' is not defined

# %%
gcd(x, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 gcd(x, N)
#
# NameError: name 'x' is not defined

# %%
# Much less likely to be relatively prime to phi(N)
gcd(x, (p-1)*(q-1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Much less likely to be relatively prime to phi(N)
# ----> 2 gcd(x, (p-1)*(q-1))
#
# NameError: name 'x' is not defined

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
# No reason to try such a big x, let's just try x = 2
x = 2

# %%
pow(x, e*d - 1, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pow(x, e*d - 1, N)
#
# NameError: name 'd' is not defined

# %%
pow(2, e*d - 1, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 pow(2, e*d - 1, N)
#
# NameError: name 'd' is not defined

# %%
from Lab5_Helper import factor_out_2

# %%
factor_out_2(48)
# Out:
# (4, 3)

# %%
(2**4)*3
# Out:
# 48

# %%
factor_out_2(100)
# Out:
# (2, 25)

# %%
(2**2)*25
# Out:
# 100

# %%
factor_out_2(1024)
# Out:
# (10, 1)

# %%
(2**10)*1
# Out:
# 1024

# %%
factor_out_2(e*d-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 factor_out_2(e*d-1)
#
# NameError: name 'd' is not defined

# %%
(e*d-1)%32
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 (e*d-1)%32
#
# NameError: name 'd' is not defined

# %%
(e*d-1)%64
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 (e*d-1)%64
#
# NameError: name 'd' is not defined

# %%
pow(2, e*d - 1, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 pow(2, e*d - 1, N)
#
# NameError: name 'd' is not defined

# %%
# Want a^2 = 1 mod N
a = pow(2, (e*d - 1)/2, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Want a^2 = 1 mod N
# ----> 2 a = pow(2, (e*d - 1)/2, N)
#
# NameError: name 'd' is not defined

# %%
# Only use `x//y` if you know y divides x
a = pow(2, (e*d - 1)//2, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Only use `x//y` if you know y divides x
# ----> 2 a = pow(2, (e*d - 1)//2, N)
#
# NameError: name 'd' is not defined

# %%
pow(a, 2, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 pow(a, 2, N)
#
# NameError: name 'a' is not defined

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
# Up to (e*d - 1)//32 is safe, because 32 divides e*d - 1 in this particular case
a = pow(2, (e*d - 1)//4, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 # Up to (e*d - 1)//32 is safe, because 32 divides e*d - 1 in this particular case
# ----> 2 a = pow(2, (e*d - 1)//4, N)
#
# NameError: name 'd' is not defined

# %%
# Should still have pow(a,2,N) = 1
pow(a, 2, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Should still have pow(a,2,N) = 1
# ----> 2 pow(a, 2, N)
#
# NameError: name 'a' is not defined

# %%
# Is a a nontrivial square root of unity
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Is a a nontrivial square root of unity
# ----> 2 a
#
# NameError: name 'a' is not defined

# %%
a = pow(2, (e*d - 1)//8, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 a = pow(2, (e*d - 1)//8, N)
#
# NameError: name 'd' is not defined

# %%
pow(a, 2, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 pow(a, 2, N)
#
# NameError: name 'a' is not defined

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a = pow(2, (e*d - 1)//16, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 a = pow(2, (e*d - 1)//16, N)
#
# NameError: name 'd' is not defined

# %%
pow(a, 2, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 pow(a, 2, N)
#
# NameError: name 'a' is not defined

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
N-1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 N-1
#
# NameError: name 'N' is not defined

# %%
gcd(a+1, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 gcd(a+1, N)
#
# NameError: name 'a' is not defined

# %%
gcd(a-1, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 gcd(a-1, N)
#
# NameError: name 'a' is not defined

# %%
p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 p
#
# NameError: name 'p' is not defined

# %%
q
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 q
#
# NameError: name 'q' is not defined

# %%
a2 = pow(3, (e*d-1)//8, N)
a2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 a2 = pow(3, (e*d-1)//8, N)
#       2 a2
#
# NameError: name 'd' is not defined

# %%
N
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 N
#
# NameError: name 'N' is not defined

# %%
# The base x = 3 also worked
gcd(a2-1, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 # The base x = 3 also worked
# ----> 2 gcd(a2-1, N)
#
# NameError: name 'a2' is not defined
