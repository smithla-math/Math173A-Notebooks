# %%
# !pip install pycryptodome
# Out:
# Requirement already satisfied: pycryptodome in c:\program files\python39\lib\site-packages (3.23.0)
# WARNING: You are using pip version 21.0.1; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.

# %%
from Crypto.Util.number import getPrime, getRandomNBitInteger
from sympy.ntheory import n_order, nextprime, isprime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from Crypto.Util.number import getPrime, getRandomNBitInteger
#       2 from sympy.ntheory import n_order, nextprime, isprime
#
# ModuleNotFoundError: No module named 'Crypto'

# %%
p = getPrime(100)
q = getPrime(100)
N = p*q
phiN = (p-1)*(q-1)
print(p)
print(q)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 p = getPrime(100)
#       2 q = getPrime(100)
#       3 N = p*q
#
# NameError: name 'getPrime' is not defined

# %%
from math import gcd

# %%
for e in range(3, 20):
    print(e, gcd(e, phiN))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 for e in range(3, 20):
# ----> 2     print(e, gcd(e, phiN))
#
# NameError: name 'phiN' is not defined

# %%
# NOT USEFUL NOT USEFUL NOT USEFUL
for e in range(3, 20):
    print(e, gcd(e, N))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # NOT USEFUL NOT USEFUL NOT USEFUL
#       2 for e in range(3, 20):
# ----> 3     print(e, gcd(e, N))
#
# NameError: name 'N' is not defined

# %%
# Based on the gcd(e, phiN) computation
e = 5
d = pow(e, -1, phiN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Based on the gcd(e, phiN) computation
#       2 e = 5
# ----> 3 d = pow(e, -1, phiN)
#
# NameError: name 'phiN' is not defined

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 d
#
# NameError: name 'd' is not defined

# %%
phiN
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 phiN
#
# NameError: name 'phiN' is not defined

# %%
# Posted by Bob (these roles are not well-defined)
print(N)
print(e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Posted by Bob (these roles are not well-defined)
# ----> 2 print(N)
#       3 print(e)
#
# NameError: name 'N' is not defined

# %%
# Alice chooses a secret number x, smaller than N
x = getRandomNBitInteger(150)
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Alice chooses a secret number x, smaller than N
# ----> 2 x = getRandomNBitInteger(150)
#       3 x
#
# NameError: name 'getRandomNBitInteger' is not defined

# %%
# How does Alice encrypt x? Formula can't involve phi(N) phiN because phiN is not public
c = pow(x, e, N)
c # gets posted publicly
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # How does Alice encrypt x? Formula can't involve phi(N) phiN because phiN is not public
# ----> 2 c = pow(x, e, N)
#       3 c
#
# NameError: name 'x' is not defined

# %%
# How does Bob find x from c?
pow(c, d, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # How does Bob find x from c?
# ----> 2 pow(c, d, N)
#
# NameError: name 'c' is not defined

# %%
from math import sqrt

# %%
p = 873113365496510728361088335653
q = 1189460389891662892796812437329
N = p*q
phiN = (p-1)*(q-1)

# %%
b = phiN - N - 1
c = N

# %%
(-b + sqrt(b**2 - 4*c))/2
# Out:
# 1.189460389891663e+30

# %%
(-b - sqrt(b**2 - 4*c))/2
# Out:
# 8.731133654965107e+29

# %%
from numpy import sqrt

# %%
(-b + sqrt(b**2 - 4*c + 0.))/2
# Out:
# 1.189460389891663e+30

# %%
5/2
# Out:
# 2.5
